# %% [markdown]
# # Precision-Recall Curve
#
# ##### Author: [Radoslav Neychev](https://raw.githubusercontent.com/girafe-ai/ml-course/refs/heads/homeworks/contest/classic_pr_curve/radoslav-neychev), telegram: [@rads_ai](https://raw.githubusercontent.com/girafe-ai/ml-course/refs/heads/homeworks/contest/classic_pr_curve/rads_ai)

# %% [markdown]
# In this task, you need to implement a function that builds a Precision-Recall curve (specifically, the points through which the curve passes) for a given dataset. A description can be found in the sklearn documentation: [PR curve](https://raw.githubusercontent.com/girafe-ai/ml-course/refs/heads/homeworks/contest/classic_pr_curve/plot_precision_recall.html)
#
# Please note that the plot always passes through the point (0, 1), so the returned array must also contain this point.

# %% [markdown]
# Your task is to implement the function below.

# %%
import numpy as np


def build_precision_recall_curve(
    true_labels: np.ndarray, predicted_probas: np.ndarray
) -> np.ndarray:
    """
    Данная функция строит PR-кривую для задачи бинарной классификации.
    В случае, когда нет ни одного объекта положительного класса функция должна вызывать ValueError().

    Args:
        true_labels (np.ndarray): Массив истинных меток класса. Состоит из 0 и 1.
            1 считается меткой положительного класса.
        predicted_probas (np.ndarray): Массив предсказанных вероятностей принадлежности объекта
            к положительному классу.

    Returns:
        np.ndarray: Массив размерами (len(true_labels)+1, 2), где в каждой строчке стоит пара (precision, recall), первым элементом всегда идет (0, 1)
    """
    pass

# %% [markdown]
# Below is one of the tests for local solution checking:

# %%
true_labels = np.array([0, 0, 1, 1])
predicted_probas = np.array([0.1, 0.4, 0.35, 0.8])
expected = np.array([[0.0, 1.0], [0.5, 1.0], [0.5, 0.5], [1.0, 0.66666667], [1.0, 0.5]])
result = build_precision_recall_curve(true_labels, predicted_probas)
assert np.allclose(result, expected, atol=1e-6)

# %% [markdown]
# Submit the implemented `build_precision_recall_curve` function (together with the `numpy` import) to the contest.
#
# Good luck!
